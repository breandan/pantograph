# %%
from pantograph import PGraph
b = 1
r = 2 + b
e = 1 + r
a = 1 + e
n = 2 + a
d = 1 + n
a = 1 + d
n = 3 + a
z = 'Hello '
y = ' Pantograph '
a = z + y + '!'
pg = PGraph(n)

# %%
pg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="3012pt" height="116pt"
#  viewBox="0.00 0.00 3011.57 116.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-112 3007.5721,-112 3007.5721,4 -4,4"/>
# <!-- gast.gast.Name object at 0x7f6edd17f0f0 -->
# <g id="node1" class="node">
# <title>gast.gast.Name object at 0x7f6edd17f0f0</title>
# <ellipse fill="none" stroke="#000000" cx="157.286" cy="-90" rx="157.0724" ry="18"/>
# <text text-anchor="middle" x="157.286" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#000000">gast.gast.Name object at 0x7f6edd17f0f0</text>
# ...

# %%
print(pg.src)
# Out:
# from pantograph import PGraph
#
# z = 'Hello '
# y = ' Pantograph '
# a = z + y + '!'
# pg = PGraph(a, z, y)
# pg.src
# pg
# from pantograph import PGraph
# b = 1
# r = 2 + b
# e = 1 + r
# a = 1 + e
# n = 2 + a
# d = 1 + n
# a = 1 + d
# n = 3 + a
# z = 'Hello '
# y = ' Pantograph '
# a = z + y + '!'
# pg = PGraph(a, z, y)
# pg.src
# pg
# pg.src
# pg
# print(pg.src)
# from pantograph import PGraph
# b = 1
# r = 2 + b
# e = 1 + r
# a = 1 + e
# n = 2 + a
# d = 1 + n
# a = 1 + d
# n = 3 + a
# z = 'Hello '
# y = ' Pantograph '
# a = z + y + '!'
# pg = PGraph(a, z, y, n)
# from pantograph import PGraph
# b = 1
# r = 2 + b
# e = 1 + r
# a = 1 + e
# n = 2 + a
# d = 1 + n
# a = 1 + d
# n = 3 + a
# z = 'Hello '
# y = ' Pantograph '
# a = z + y + '!'
# pg = PGraph(a, z, y, n)
# pg.src
# pg
# print(pg.src)
# pg
# print(pg.src)
# from pantograph import PGraph
# b = 1
# r = 2 + b
# e = 1 + r
# a = 1 + e
# n = 2 + a
# d = 1 + n
# a = 1 + d
# n = 3 + a
# z = 'Hello '
# y = ' Pantograph '
# ...
